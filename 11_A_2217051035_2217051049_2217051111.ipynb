# %% [markdown]
# #UTP SDA
# KELOMPOK 11
# 1. Atikah Oktaria (2217051035)
# 2. Nazwa Sophia Nadine Effendi (2217051049)
# 3. Theresia Tri Oktavia (2217051111)

# %%
barang = ["Pensil\t", "Pena\t", "Spidol\t", "Penghapus\t", "Correction Tape", "Penggaris\t", "Buku\t"]
harga = [2000, 2500, 4000, 2000, 8000, 8000, 5000]

def pemesanan():
  print("-----------------------------------")
  print("|   PRODUK-PRODUK YANG TERSEDIA   |")
  print("-----------------------------------")
  for i in range(7) :
    print("|",i+1, barang[i], "\t|Rp.", harga[i],"|")
  print("-----------------------------------")

  jenis_barang = int(input("Masukkan produk yang ingin dibeli (1-7)  : "))
  if jenis_barang > 7:
      print("Barang Tidak Tersedia")
  else:
      pesanan_barang = barang[jenis_barang-1]
      pesanan_harga = harga[jenis_barang-1]
      quantity = int(input("Masukkan jumlah produk yang ingin dibeli : "))
      total_pesanan = (quantity * pesanan_harga)
      os.system("cls")

      print(" "" ")
      print('=' * 50)
      print("|\t   BERIKUT RINCIAN PESANAN ANDA\t\t |")
      print('=' * 50)
      print("|Barang \t\t:", pesanan_barang, "\t |")
      print('-' * 50)
      print("|Jumlah \t\t:", quantity, "\t\t\t |")
      print('-' * 50)
      print("|Total harga\t\t: Rp.", total_pesanan, "\t\t |")
      print('=' * 50)
      print(" "" ")
      print('=' * 50)
      saldo = int(input("Saldo Anda\t\t: Rp. "))
      if saldo >= total_pesanan :
          print("Kembalian\t\t: Rp.", saldo - total_pesanan)
          print('=' * 50)
      while saldo < total_pesanan:
          print('=' * 50)
          print("\n\t     Saldo Anda tidak cukup!\t\t ")
          print('=' * 50)
          print("Silahkan melakukan pembayaran ulang!")
          saldo = int(input("Uang Anda\t\t: Rp. "))
          if saldo >= total_pesanan :
              print("Kembalian\t\t: Rp.", saldo - total_pesanan)
              print('=' * 50)
    

class customer :
  def __init__(self) :
    self.nama = input("Masukkan nama Anda \t: ")
    self.nomor_hp = input("Masukkan no hp Anda \t: ")
    self.alamat = input("Masukkan alamat Anda \t: ")

  def display_cust(self) :
    print('=' * 100)
    print("\t\t\t\t Terima kasih", self.nama, "atas pesanan Anda")
    print("\t\t Kami akan segera mengemas lalu mengirim pesanan Anda ke alamat", self.alamat)
    print("\t Apabila ada kendala dalam pesanan Anda, kami akan menghubungi nomor hp Anda", self.nomor_hp)
    print('=' * 100)


import os

print("    <==========================================================================>")
print("  <====================| SELAMAT DATANG DI ATK ONLINE JAYA |=====================>")
print("<======================|    JL ABCDEFGHIJKLMN, NOMOR 000   |=======================>")
print("  <====================|        WA: 081213141516           |=====================>")
print("    <==========================================================================>\n")
print("Mohon isi data diri singkat dibawah ini")
info = customer()
os.system("cls")
while True :
  pemesanan()
  pesan_lagi=input("Apakah Anda ingin memesan lagi? (Y/T) : ")
  os.system("cls")
  if pesan_lagi != 'Y' :
    break
info.display_cust()
# Out:
#     <==========================================================================>
#   <====================| SELAMAT DATANG DI ATK ONLINE JAYA |=====================>
# <======================|    JL ABCDEFGHIJKLMN, NOMOR 000   |=======================>
#   <====================|        WA: 081213141516           |=====================>
#     <==========================================================================>
#
# Mohon isi data diri singkat dibawah ini
# Masukkan nama Anda 	: ss
# Masukkan no hp Anda 	: 33
# Masukkan alamat Anda 	: ss
# -----------------------------------
# |   PRODUK-PRODUK YANG TERSEDIA   |
# -----------------------------------
# | 1 Pensil	 	|Rp. 2000 |
# | 2 Pena	 	|Rp. 2500 |
# | 3 Spidol	 	|Rp. 4000 |
# | 4 Penghapus	 	|Rp. 2000 |
# | 5 Correction Tape 	|Rp. 8000 |
# | 6 Penggaris	 	|Rp. 8000 |
# | 7 Buku	 	|Rp. 5000 |
# -----------------------------------
# Masukkan produk yang ingin dibeli (1-7)  : 1
# Masukkan jumlah produk yang ingin dibeli : 3
#
# ==================================================
# |	   BERIKUT RINCIAN PESANAN ANDA		 |
# ==================================================
# |Barang 		: Pensil	 	 |
# --------------------------------------------------
# |Jumlah 		: 3 			 |
# --------------------------------------------------
# |Total harga		: Rp. 6000 		 |
# ==================================================
#
# ==================================================
# Saldo Anda		: Rp. 200
# ==================================================
#
# 	     Saldo Anda tidak cukup!
# ==================================================
# Silahkan melakukan pembayaran ulang!
